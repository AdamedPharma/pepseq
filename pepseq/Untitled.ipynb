# %%
correct_peptide_json = {
        "sequence": "H{aMeAla}QGTYCDAQCYS",
        "internal_modifications": [],
        "C_terminus": "NH2",
        "N_terminus": "H",
        "pepseq_format": "H~H{aMeAla}QGTY{Cys(R1)}DAQ{Cys(R2)}YS~NH2",
        "external_modifications": [
            {
                "smiles": "[1*]CC(=O)NCC[C@H](NC(=O)C[2*])C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O",
                "max_attachment_point_id": 2,
                "attachment_points_on_sequence": {
                    1: {
                        "attachment_point_id": "1",
                        "ResID": "7",
                        "AtomName": "SG",
                        "ResidueName": "Cys",
                    },
                    2: {
                        "attachment_point_id": "2",
                        "ResID": "11",
                        "AtomName": "SG",
                        "ResidueName": "Cys",
                    },
                },
            }
        ],
    }

# %%
correct_peptide_json_2 = {
        "sequence": "H{aMeAla}QGTYCDAQCYS",
        "internal_modifications": [],
        "external_modifications": [
            {
                "smiles": "[1*]CC(=O)N[C@@H](CCNC(=O)C[2*])C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O",
                "max_attachment_point_id": 2,
                "attachment_points_on_sequence": {
                    1: {
                        "attachment_point_id": 1,
                        "ResID": "11",
                        "AtomName": "SG",
                        "ResidueName": "",
                    },
                    2: {
                        "attachment_point_id": 2,
                        "ResID": "7",
                        "AtomName": "SG",
                        "ResidueName": "",
                    },
                },
            }
        ],
        "C_terminus": "NH2",
        "N_terminus": "H",
        "pepseq_format": "H~H{aMeAla}QGTY{Cys(R2)}DAQ{Cys(R1)}YS~NH2",
    }

# %%
correct_peptide_json_2 == correct_peptide_json
# Out:
# False

# %%
smiles1 = "[1*]CC(=O)N[C@@H](CCNC(=O)C[2*])C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O"
smiles2 = "[1*]CC(=O)NCC[C@H](NC(=O)C[2*])C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O"

# %%
import rdkit

def mols_are_identical(mol1, mol2):
    are_identical = mol1.HasSubstructMatch(
        mol2, useChirality=True
    ) and mol2.HasSubstructMatch(mol1, useChirality=True)
    return are_identical


def smiles_are_identical(smi1, smi2):
    mol1 = rdkit.Chem.MolFromSmiles(smi1)
    mol2 = rdkit.Chem.MolFromSmiles(smi2)
    return mols_are_identical(mol1, mol2)

# %%
smiles_are_identical(smiles1, smiles2)
# Out:
# False

# %%
correct_smiles = "[H]N[C@@H](Cc1c[nH]cn1)C(=O)NC(C)(C)C(=O)N[C@@H](CCC(N)=O)C(=O)NCC(=O)N[C@H](C(=O)N[C@@H](Cc1ccc(O)cc1)C(=O)N[C@H]1CSCC(=O)NCC[C@@H](C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O)NC(=O)CSC[C@@H](C(=O)N[C@@H](Cc2ccc(O)cc2)C(=O)N[C@@H](CO)C(N)=O)NC(=O)[C@H](CCC(N)=O)NC(=O)[C@H](C)NC(=O)[C@H](CC(=O)O)NC1=O)[C@@H](C)O"

# %%
mol = rdkit.Chem.MolFromSmiles( correct_smiles )

# %%
rdkit.Chem.Draw.MolToImage(mol, size=(640, 640))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x640>

# %%
smiles1 = "[H]N[C@@H](Cc1c[nH]cn1)C(=O)NC(C)(C)C(=O)N[C@@H](CCC(N)=O)C(=O)NCC(=O)N[C@H](C(=O)N[C@@H](Cc1ccc(O)cc1)C(=O)N[C@H]1CSCC(=O)NCC[C@@H](C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O)NC(=O)CSC[C@@H](C(=O)N[C@@H](Cc2ccc(O)cc2)C(=O)N[C@@H](CO)C(N)=O)NC(=O)[C@H](CCC(N)=O)NC(=O)[C@H](C)NC(=O)[C@H](CC(=O)O)NC1=O)[C@@H](C)O"
smiles2 = "[H]N[C@@H](Cc1c[nH]cn1)C(=O)NC(C)(C)C(=O)N[C@@H](CCC(N)=O)C(=O)NCC(=O)N[C@H](C(=O)N[C@@H](Cc1ccc(O)cc1)C(=O)N[C@H]1CSCC(=O)NCC[C@@H](C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O)NC(=O)CSC[C@@H](C(=O)N[C@@H](Cc2ccc(O)cc2)C(=O)N[C@@H](CO)C(N)=O)NC(=O)[C@H](CCC(N)=O)NC(=O)[C@H](C)NC(=O)[C@H](CC(=O)O)NC1=O)[C@@H](C)O"
correct_smiles = "[H]N[C@@H](Cc1c[nH]cn1)C(=O)NC(C)(C)C(=O)N[C@@H](CCC(N)=O)C(=O)NCC(=O)N[C@H](C(=O)N[C@@H](Cc1ccc(O)cc1)C(=O)N[C@H]1CSCC(=O)NCC[C@@H](C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O)NC(=O)CSC[C@@H](C(=O)N[C@@H](Cc2ccc(O)cc2)C(=O)N[C@@H](CO)C(N)=O)NC(=O)[C@H](CCC(N)=O)NC(=O)[C@H](C)NC(=O)[C@H](CC(=O)O)NC1=O)[C@@H](C)O"

smiles_are_identical( smiles1, smiles2 )
smiles_are_identical( smiles1, correct_smiles )
# Out:
# True

# %%
sorted([(7,1), (12, 1), (5,3)])
# Out:
# [(5, 3), (7, 1), (12, 1)]

# %%
correct_peptide_json = {
        "sequence": "H{aMeAla}QGTYCDAQCYS",
        "internal_modifications": [],
        "C_terminus": "NH2",
        "N_terminus": "H",
        "pepseq_format": "H~H{aMeAla}QGTY{Cys(R1)}DAQ{Cys(R2)}YS~NH2",
        "external_modifications": [
            {
                "smiles": "[1*]CC(=O)NCC[C@H](NC(=O)C[2*])C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O",
                "max_attachment_point_id": 2,
                "attachment_points_on_sequence": {
                    1: {
                        "attachment_point_id": "1",
                        "ResID": "7",
                        "AtomName": "SG",
                        "ResidueName": "Cys",
                    },
                    2: {
                        "attachment_point_id": "2",
                        "ResID": "11",
                        "AtomName": "SG",
                        "ResidueName": "Cys",
                    },
                },
            }
        ],
    }

# %%
import json
from BuildingModifiedPeptideFromPeptideJSON import get_smiles_from_peptide_json

db_path = "Peptide/database/db.json"

with open(db_path) as fp:
    db_json = json.load(fp)


correct_smiles = get_smiles_from_peptide_json(correct_peptide_json, db_json)
# Out:
# [14:59:01] WARNING: not removing hydrogen atom with dummy atom neighbors

# %%
smiles
# Out:
# '[H]N[C@@H](Cc1c[nH]cn1)C(=O)NC(C)(C)C(=O)N[C@@H](CCC(N)=O)C(=O)NCC(=O)N[C@H](C(=O)N[C@@H](Cc1ccc(O)cc1)C(=O)N[C@H]1CSCC(=O)NCC[C@@H](C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O)NC(=O)CSC[C@@H](C(=O)N[C@@H](Cc2ccc(O)cc2)C(=O)N[C@@H](CO)C(N)=O)NC(=O)[C@H](CCC(N)=O)NC(=O)[C@H](C)NC(=O)[C@H](CC(=O)O)NC1=O)[C@@H](C)O'

# %%
from BuildPeptideJSONFromSMILES import decompose_peptide_smiles_with_termini, from_smiles_to_pepseq_and_one_mod_smiles_strings

output_peptide_json = decompose_peptide_smiles_with_termini(correct_smiles, db_json)

# %%
correct_peptide_json == output_peptide_json
# Out:
# False

# %%
correct_peptide_json = {
        "sequence": "H{aMeAla}QGTYCDAQCYS",
        "internal_modifications": [],
        "C_terminus": "NH2",
        "N_terminus": "H",
        "pepseq_format": "H~H{aMeAla}QGTY{Cys(R1)}DAQ{Cys(R2)}YS~NH2",
        "external_modifications": [
            {
                "smiles": "[1*]CC(=O)NCC[C@H](NC(=O)C[2*])C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O",
                "max_attachment_point_id": 2,
                "attachment_points_on_sequence": {
                    1: {
                        "attachment_point_id": "1",
                        "ResID": "7",
                        "AtomName": "SG",
                        "ResidueName": "Cys",
                    },
                    2: {
                        "attachment_point_id": "2",
                        "ResID": "11",
                        "AtomName": "SG",
                        "ResidueName": "Cys",
                    },
                },
            }
        ],
    }


out_json = {'sequence': 'H{aMeAla}QGTYCDAQCYS',
 'internal_modifications': [],
 'external_modifications': [{'smiles': '[1*]CC(=O)NCC[C@H](NC(=O)C[2*])C(=O)NCCC(=O)NCCOC(=O)NCC[C@H](NC(=O)CCC(=O)O)C(=O)O',
   'max_attachment_point_id': 2,
   'attachment_points_on_sequence': {1: {'attachment_point_id': "1",
     'ResID': '7',
     'AtomName': 'SG',
     'ResidueName': 'Cys'},
    2: {'attachment_point_id': "2",
     'ResID': '11',
     'AtomName': 'SG',
     'ResidueName': 'Cys'}}}],
 'C_terminus': 'NH2',
 'N_terminus': 'H',
 'pepseq_format': 'H~H{aMeAla}QGTY{Cys(R1)}DAQ{Cys(R2)}YS~NH2'}

# %%
correct_peptide_json == out_json
# Out:
# True
